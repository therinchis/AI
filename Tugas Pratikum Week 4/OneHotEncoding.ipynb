# %% [markdown]
# Rayhan Christian Wewengkang (2024081005) One Hot Encoding

# %%
import pandas as pd

# %%
data = pd.DataFrame({
 'Warna': ['Merah', 'Hijau', 'Biru', 'Hijau']
})
encoded = pd.get_dummies(data)
print(encoded)
# Out:
#    Warna_Biru  Warna_Hijau  Warna_Merah
# 0       False        False         True
# 1       False         True        False
# 2        True        False        False
# 3       False         True        False
